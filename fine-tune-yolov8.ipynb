# %%
# !pip install -q git+https://github.com/THU-MIG/yolov10.git 
# !pip install -U pyyaml 
# !pip install -U roboflow 
# !pip install -U ultralytics==8.1.38 
# !pip install -U supervision
# !pip install -U ipywidgets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 723.3/723.3 kB 19.8 MB/s eta 0:00:0000:01
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.1.34
#     Uninstalling ultralytics-8.1.34:
#       Successfully uninstalled ultralytics-8.1.34
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.5/151.5 kB 6.6 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.38 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5845.9/8062.4 GB disk)

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="YOUR API KEY")
project = rf.workspace("WORKSPACE ID").project("PROJECT ID")
dataset = project.version(1).download("folder")
# Out:
# mkdir: cannot create directory '{HOME}/datasets': No such file or directory
# [Errno 2] No such file or directory: '{HOME}/datasets'
# /kaggle/working
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Thesis-Dental-1 in folder:: 100%|██████████| 2115/2115 [00:00<00:00, 6014.61it/s]

# %% [markdown]
# # TRAIN

# %%
#change name of folder to 'val' 
# !mv /kaggle/working/Thesis-Dental-1/valid /kaggle/working/Thesis-Dental-1/val
# Out:
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.

# %%
from ultralytics import YOLO

# Load a model

model = YOLO("yolov8n-cls.pt")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data="/kaggle/working/Thesis-Dental-1", epochs=25, imgsz=640, batch = 32)
# Out:
# New https://pypi.org/project/ultralytics/8.2.99 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.38 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %% [markdown]
# # val

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n-cls.pt")  # load an official model
model = YOLO("/kaggle/working/runs/classify/train2/weights/best.pt")  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.top1  # top1 accuracy
metrics.top5  # top5 accuracy
# Out:
# Ultralytics YOLOv8.1.38 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1442566 parameters, 0 gradients, 3.3 GFLOPs
# train: /kaggle/working/Thesis-Dental-1/train... found 1464 images in 6 classes ✅
# val: /kaggle/working/Thesis-Dental-1/val... found 418 images in 6 classes ✅
# test: /kaggle/working/Thesis-Dental-1/test... found 210 images in 6 classes ✅
# val: Scanning /kaggle/working/Thesis-Dental-1/val... 418 images, 0 corrupt: 100%|██████████| 418/418 [00:00<?, ?it/s]
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#                classes   top1_acc   top5_acc: 100%|██████████| 27/27 [00:04<00:00,  5.66it/s]
#                    all      0.962          1
# Speed: 1.0ms preprocess, 3.3ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/val
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/kaggle/working/runs/classify/train2/weights/best.pt")  # load the trained model

# Export the model to ONNX
model.export(format="onnx")
# Out:
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# Ultralytics YOLOv8.1.38 🚀 Python-3.10.14 torch-2.4.0 CPU (Intel Xeon 2.00GHz)
# ...
